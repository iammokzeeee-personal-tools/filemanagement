# %%
class File:

    def read():
        return

    def write():
        return

    def delete():
        return

    def create():
        return

    def open():
        return

    def append():
        return

    def close():
        return
    
    def move():
        return
    
    def copy():
        return
    
    def size():
        return
    
    def get_permissions():
        return
    
    def set_permissions():
        return
    
    def compress():
        return
    
    def decompress():
        return
    
    def encrypt():
        return
    
    def decrypt():
        return
    
    def checksum():
        return
    
    def log():
        return
    
    def debug():
        return

class Directory:

    def contents():
        return
    
    def create():
        return
    
    def delete():
        return
